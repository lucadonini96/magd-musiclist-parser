# %%
import os
import re
import pandas as pd
import docx
import warnings

def italic_markup(r):
    leading_white = (lambda x: x.group() if x is not None else "")(re.search(r'^\s+',r))
    if len(leading_white)<len(r):
        trailing_white = (lambda x: x.group() if x is not None else "")(re.search(r'\s+$',r))
    else:
        trailing_white = ""
    trimmed = r[len(leading_white):(None if len(trailing_white)==0 else -len(trailing_white))]
    if len(trimmed)>0:
        trimmed = "<i>" + trimmed + "</i>"
    return leading_white + trimmed + trailing_white

def getText(filename,markup=False):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        if markup:
            for run in para.runs:
                if run.italic:
                    #run.text = "<i>"+run.text+"</i>"
                    run.text = italic_markup(run.text)
                #print(run.text,run.italic)
        fullText.append(para.text)
    return '\n'.join(fullText)

import datetime

class musiclist:
    term = None
    year = None
    services = []
    
    keys = ['serviceid',
     'servicetype',
     'servicedate',
     'liturgicalday',
     'hymns',
     'introit',
     'responses',
     'psalm',
     'canticles',
     'anthem',
     'requiem',
     'setting',
     'motet',
     'cantata',
     'preacher',
     'sermon topic',
     'voluntary',
     'organist',
     'extranotes']
    
    def __init__(self,inputfile,keys=None,index=None,firstid=None):
        self.inputfile = inputfile
        
        if keys is not None:
            self.keys = keys
            
        if index is not None:
            self.index = index
        else:
            self.index = self.keys[0]
        
        self.rawtext = getText(inputfile,markup=False).split('\n')
        self.rawtext_markup = getText(inputfile,markup=True).split('\n')
        self.parse(self.rawtext,self.rawtext_markup)
        
        self.musiclist_df = pd.DataFrame(self.services,columns=self.keys).set_index(self.index)
        #print(self.musiclist_df)
        if firstid is not None:
            self.musiclist_df.index = list(range(firstid, firstid+len(self.musiclist_df)))
            self.musiclist_df.index.name = self.index
        
    def parse(self,rawtext,rawtext_markup):
        
        # Find current term and year
        for line in rawtext:
            match = re.search(r'^\s?(Michaelmas|Lent|Easter) Term [0-9]{2,4}\s?$',line)
            if match is not None:
                s = match.group().split(' ')
                #print(s)
                self.term = s[0]
                self.year = int(s[2])

        # Find service dates
        matchlines = []
        servicedates = []
        liturgicaldays = []
        for idx,line in enumerate(rawtext):
            try:
                dt = datetime.datetime.strptime(line.title().strip(),"%A %d %B")
                dt = dt.replace(year=self.year)
                liturgicalday = rawtext[idx+1].title()
                matchlines.append(idx)
                servicedates.append(dt)
                liturgicaldays.append(liturgicalday)
                print(dt,idx)
            except ValueError:
                pass
        matchlines.append(None)
        #print(matchlines)
        
        # Now parse each day
        for j in range(len(matchlines)-1):
            dayraw = rawtext[matchlines[j]:matchlines[j+1]]
            dayraw_markup = rawtext_markup[matchlines[j]:matchlines[j+1]]
            date = servicedates[j]
            liturgicalday = liturgicaldays[j]
            
            print('\n'.join(dayraw))
            
            # Find time and service type (note there may be more than one service on a given day)
            timematchlines = []
            servicetimes = []
            servicetypes = []
            for idx,line in enumerate(dayraw):
                match = re.search(r'^\s?[0-9]{,2}\.[0-9]{2} ?(am|pm)\s.+$',line)
                if match is not None:
                    s = [s.strip() for s in match.group().split("\t")]
                    s = list(filter(None,s))
                    
                    print(s)
                    try:
                        t = datetime.datetime.strptime(s[0],'%I.%M %p')
                    except ValueError:
                        t = datetime.datetime.strptime(s[0],'%I.%M%p')
                    t = t.replace(year = date.year, month = date.month, day = date.day)
                    #print(t)
                    #datetime.datetime.strptime('9.00 am','%I.%M %p')
                    timematchlines.append(idx)
                    servicetimes.append(t)
                    servicetypes.append(s[1])
            timematchlines.append(None)
            #print(timematchlines)
            
            # Now parse each service
            for k in range(len(timematchlines)-1):
                serviceraw = dayraw[timematchlines[k]:timematchlines[k+1]]
                serviceraw_markup = dayraw_markup[timematchlines[k]:timematchlines[k+1]]
                t = servicetimes[k]
                servicetype = servicetypes[k]
                musiclistraw = serviceraw[1:]
                musiclistraw_markup = serviceraw_markup[1:]
                
                musicdict = self.parseservicemusic(musiclistraw,musiclistraw_markup)
                
                service_dict = {}
                service_dict['servicedate'] = t.strftime("%Y-%m-%d %H:%M:%S")
                service_dict['servicetype'] = servicetype
                service_dict['liturgicalday'] = liturgicalday
                
                service_dict = {**service_dict, **musicdict}
            
                self.services.append(service_dict)
                
                print("..........................")
                print(t)
                print(service_dict)
                #print(servicetype)
                #print()
                #print('\n'.join(musiclistraw))
                
            
            #print("---------------------------------")
            #print('\n'.join(dayraw))
            #print(service_dict)
                
        
    def parseservicemusic(self,musiclistraw,musiclistraw_markup=None):
        if musiclistraw_markup is None:
            musiclistraw_markup = musiclistraw
        musicdict = {}
        for line,line_markup in zip(musiclistraw,musiclistraw_markup):
            linelist = [s.strip() for s in line.split("\t")]
            keyval = list(filter(None,linelist))
            linelist_markup = line_markup.split("\t")
            keyval_markup = list(filter(None,linelist_markup))
            #print(keyval)
            if len(keyval) == 2:
                if(keyval[0].lower() in self.keys):
                    musicdict[keyval[0].lower()] = keyval_markup[1]
                elif keyval[0].lower() == 'sermon':
                    #print(keyval_markup)
                    s = keyval[1]
                    s_markup = keyval_markup[1]
                    preacher = s_markup.split('<')[0].strip()
                    sermontopic = s[len(preacher):].strip()
                    musicdict['preacher'] = preacher
                    musicdict['sermon topic'] = sermontopic
                else:
                    warnings.warn("The key '{:}' was not recognised.".format(keyval[0].lower()))
                    
                    
        #print(musicdict)
        return musicdict
    
    def export(self,outfile):
        #writer = pd.ExcelWriter(outfile,datetime64_format='yyyy-mm-dd hh:mm:ss')
        self.musiclist_df.to_excel(outfile,sheet_name='magdservices')

# %%
# inputfile = "data/Service booklet E19v2 changes accepted.docx"
inputfile = "data/Service booklet L19 v3.docx"

# %%
rawtext = getText(inputfile,markup=True).split('\n')
print(getText(inputfile,markup=True))
# Out:
# Magdalene College
#
#
#
#
#
#
# Chapel Music List
#
#
#
#
#
# Lent Term 2019
#
#
#
# <i>Please do not remove</i>
#
#
#
#
#
#
#
#
# The Chaplain:
# The Precentor and Director of Music:
# The Assistant Organist:
# The Junior Organ Scholar:
# The Honorary Assistant Organist:
#
# The Rev’d Sarah Atkins
# Mr Graham Walker
# Mariëtta van der Tol
#  Ivo Macdonald
# Mr Jonathan Hellyer Jones
#
#
#
#
#
# Times of Services
#
# 	Sunday:	9.00 am Holy Communion
# 		6.00 pm Choral Evensong
# 	Monday:	8.30 am Morning Prayer
#
# 	Tuesday:	8.30 am Morning Prayer
#
# 	Wednesday:	8.30 am Morning Prayer
#
# 	Thursday:	8.30 am Morning Prayer
# 		6.15 pm Choral Evensong
# <i>except 7, 21 February, 7 March</i>
# 	Friday:	8.30 am Morning Prayer
#
#
# holy communion follows a printed order of service in contemporary language. There are three hymns and a short address.
#
# EVENSONG is sung according to the Book of Common Prayer, and can be found on the laminated sheets in the stalls. Evening Prayer is celebrated twice a term at 7pm on the Sundays immediately before and after term.
#
# Compline follows the monastic tradition and is generally sung in English. This short service is held twice each term on Wednesdays at 9.30pm.
#
# CORPORATE COMMUNION is celebrated on Wednesday 6 February at 6.15pm
#
# COLLECTIONS this term go to Kwasa College, a primary school in Johannesburg providing education for orphaned and vulnerable children.
#
#
#
#
#
# SUNDAY 20 JANUARY
# SECOND SUNDAY AFTER THE EPIPHANY
#
#
# <i>9.00 am</i>	<i>College Eucharist</i>
#
# Hymns		137, Christ is our light t. AM97, 47
#
# <i>6.00 pm</i>	<i>Choral Evensong</i> <i>with the blessing of the new Icon of St Mary Magdalene</i>
#
# Responses	Oxley
# Psalm		102 vv 1-11
# Canticles	Plainsong <i>Magnifica</i><i>t</i>; Wood <i>Nunc Dimittis</i>
# Anthem		Britten <i>New Year Carol</i>
# Sermon		The Master <i>Blessed are the poor in spirit</i>
# Hymns		174 t. 490, 52
#
#
# THURSDAY 24 JANUARY
#
# <i>6.15 pm</i>	<i>Choral Evensong</i>
#
# Responses	Oxley
# Psalm		118 vv 19-29
# Canticles	Sumsion in G
# Anthem		Byrd <i>Kyrie Eleison</i> <i>(4-part Mass)</i>
# Hymns		48, 57
#
#
#
#
# SUNDAY 27 JANUARY
# THIRD SUNDAY AFTER THE EPIPHANY
#
#
#
# <i>9.00 am</i>	<i>College Eucharist</i>
#
#
# Hymns		55, The kingdom of God t. AM 569i, 297
#
# <i>6.00 pm</i>	<i>Choral Evensong</i>
#
# Responses	Oxley
# Psalm		120
# Canticles	Sumsion in G
# Anthem		Byrd <i>Miserere Mei</i>
# Sermon		The Chaplain <i>Blessed are those who mourn</i>
# Hymns		472ii, 82, 331
# WEDNESDAY 30 JANUARY
#
# <i>9</i><i>.30pm</i>	<i>Choral</i> <i>Compline</i>
#
#
# THURSDAY 31 JANUARY
#
# <i>6.15 pm</i>	<i>Choral Evensong</i>
#
# Responses	Oxley
# Psalm		145 vv 1-7
# Canticles	Howells <i>Collegium Regale</i>
# Anthem		Wesley <i>Lead Me, Lord</i>
# Hymns		358ii, 377
#
#
#
#
# SUNDAY 3 FEBRUARY
# CANDLEMAS
#
# <i>9.00 am</i>	<i>College Eucharist</i>
#
# Hymns	408i, Like a candle flame t. AM74, Christ be our light t. AM42
#
# <i>6.00 pm</i>	<i>Choral Evensong</i>
#
# Responses	Rose
# Psalm		18 vv 1-15
# Canticles	Howells <i>Collegium Regale</i>
# Anthem		Wood <i>Hail, Gladdening Light</i>
# Sermon		The Reverend Jon Canessa <i>Blessed are the meek</i>
# Hymns		33 (vv 1,4,5,7), 44, 437
#
#
#
#
#
#
# WEDNESDAY 6 FEBRUARY
#
# <i>6.15 pm</i>	<i>Corporate Communion</i>
#
# 	Setting	Perosi <i>Missa</i> <i>Secunda</i> <i>Pontificalis</i>
# 	Motet	Tallis <i>Verily, verily</i>
# 	Hymns	427, 295, 415 t. 346
#
# SUNDAY 10 FEBRUARY
# FIFTH SUNDAY AFTER THE EPIPHANY
#
#
#
# <i>9.00 am</i>	<i>College Eucharist</i>
#
# Hymns		378, Above the voices t. AM114, 333
#
# <i>6.00 pm</i>	<i>Choral Evensong</i>
#
# Responses	Rose
# Psalm		55 vv 1-15
# Canticles	Stanford <i>in C</i>
# Anthem		Brahms <i>Geistliches</i> <i>Lied</i>
# Sermon		Dr Pia de Simone <i>Blessed are</i> <i>those</i> <i>who hunger</i>
# Hymns		Come, my way t. The Call, 276, 368
#
#
# THURSDAY 14 February
#
# <i>6.15 pm</i>	<i>Choral Evensong</i>
#
# Responses	Rose
# Psalm		74, 13-18
# Canticles	Dyson <i>in C Minor</i>
# Anthem		Byrd S<i>anctus and Benedictus</i> <i>(4-part Mass)</i>
# Hymns		457, 446
#
#
#
#
#
# SUNDAY 17 FEBRUARY
# SEPTUAGESIMA
#
#
#
# <i>9.00 am</i>	<i>College Eucharist</i>
#
# Hymns		52, Alleluia, raise the gospel t. AM556, 394
#
#
# <i>6.00 pm</i>	<i>Choral Evensong</i>
#
# Responses	Rose
# Psalm		89 vv 1-8
# Canticles	Dyson <i>in C Minor</i>
# Anthem		Walford Davies <i>Blest are the pure in heart</i>
# Sermon		Dr Elaine Storkey <i>Blessed are the pure in heart</i>
# Hymns		431, 341, 473 (vv 1, 6-8)
#
#
# FRIDAY 22 FEBRUARY
# SAMUEL PEPYS’ BIRTHDAY
#
#
# <i>6.00</i> <i>pm</i>	<i>Choral Evensong</i>
#
# Responses	Tomkins
# Psalm		107 vv 23-30
# Canticles	Gibbons <i>Second Service</i>
# Anthem		Gibbons <i>O clap your hands</i>
# Hymns		373 t Coe Fen<i>,</i> 436
#
#
#
# SUNDAY 24 FEBRUARY
# SEXUAGESIMA/SAINT MATTHIAS
#
#
# <i>9.00 am</i>	<i>Holy Communion</i>
#
# Hymns		354, 274, O Lord my God
#
#
# <i>6.00 pm</i>	<i>Choral Evensong</i>
#
# Responses	Tomkins
# Psalm		119 vv 1-16
# Canticles	Gibbons <i>Second Service</i>
# Anthem		Mendelssohn <i>Verleih</i> <i>uns</i> <i>Frieden</i>
# Sermon		Monsignor Mark Langham <i>Blessed are the</i>   <i>peacemakers</i>
# Hymns		394, Peace, Perfect Peace t. 82, 361
#
#
#
# WEDNESDAY 27 FEBRUARY
#
# <i>9</i><i>.30pm</i>	<i>Choral</i> <i>Compline</i>
#
#
# THURSDAY 28 FEBRUARY
#
# <i>6.15 pm</i>	<i>Choral Evensong</i>
#
# Responses	Tomkins
# Psalm		137
# Canticles	Brewer <i>In D</i>
# Anthem		Tallis <i>If ye love me</i>
# Hymns		294, 357
# SUNDAY 3 MARCH
# QUINQAGESIMA
#
#
#
# <i>9.00 am</i>	<i>College Eucharist</i>
#
# Hymns		433, Jesus on the mountain peak (t. St Albinus), There is a redeemer t. AM 805
#
#
# <i>6.00 pm</i>	<i>Choral Evensong</i>
#
# Responses	Tomkins
# Psalm		15
# Canticles	Brewer <i>In D</i>
# Anthem		Purcell <i>Remember not, O Lord</i>
# Sermon		Dr Muthuraj Swamy <i>Blessed are the persecuted</i>
# Hymns		383ii, 414, And can it be
#
#
#
#
#
# WEDNESDAY 6 MARCH
#
# ASH WEDNESDAY
#
#
#
# <i>6.</i><i>.00 p</i><i>m</i>	<i>Communion with ceremony of</i> <i>ashing</i>
# Setting		Byrd <i>4-part Mass</i>
# Motet		Byrd <i>Miserere Mei</i>
# Hymns		70, 76, 75
#
#
#
#
#
#
#
#
# SUNDAY 10 MARCH
# FIRST SUNDAY IN LENT
#
#
#
# <i>9.00 am</i>	<i>College Eucharist</i>
#
# Hymns		67, 357, 420
#
# <i>6.00 pm</i>	<i>Lenten Service of Readings and Music</i>
#
#
#
#
#
#
#
#
# THURSDAY 14 MARCH
#
#
# <i>6.15 pm</i>	<i>Choral Evensong</i>
#
# Responses	Tomkins
# Psalm		74 1-12
# Canticles	Plainsong <i>Magnificat</i>; Wood <i>Nunc Dimittis</i>
# Anthem		Rheinberger <i>Abendlied</i>
# Hymns		84, 86
#
#
#
#
#
# SUNDAY 18 MARCH
# FOURTH SUNDAY IN LENT
#
#
#
# <i>9.00 am</i>	<i>College Eucharist</i>
#
#
#
#
#
# Services are discontinued until Easter Day, Sunday 21 April 2019

# %%
ml = musiclist(inputfile,firstid=None)
print(ml.term)
print(ml.year)
for s in ml.services:
    print(s)
    print()
outfile = os.path.join('output',os.path.splitext(os.path.split(inputfile)[-1])[0]+'.xlsx')
print(outfile)
ml.export(outfile)
# Out:
# 2019-01-20 00:00:00 78
# 2019-01-24 00:00:00 96
# 2019-01-27 00:00:00 109
# 2019-01-30 00:00:00 127
# 2019-01-31 00:00:00 132
# 2019-02-03 00:00:00 145
# 2019-02-06 00:00:00 166
# 2019-02-10 00:00:00 174
# 2019-02-14 00:00:00 193
# 2019-02-17 00:00:00 207
# 2019-02-22 00:00:00 227
# 2019-02-24 00:00:00 241
# 2019-02-27 00:00:00 261
# 2019-02-28 00:00:00 266
# 2019-03-03 00:00:00 275
# 2019-03-06 00:00:00 298
# 2019-03-10 00:00:00 316
# 2019-03-14 00:00:00 334
# 2019-03-18 00:00:00 349
# SUNDAY 20 JANUARY
# SECOND SUNDAY AFTER THE EPIPHANY
#
#
# 9.00 am	College Eucharist
#
# Hymns		137, Christ is our light t. AM97, 47
#
# 6.00 pm	Choral Evensong with the blessing of the new Icon of St Mary Magdalene
#
# Responses	Oxley
# Psalm		102 vv 1-11
# Canticles	Plainsong Magnificat; Wood Nunc Dimittis
# Anthem		Britten New Year Carol
# Sermon		The Master Blessed are the poor in spirit
# Hymns		174 t. 490, 52
#
#
# ['9.00 am', 'College Eucharist']
# ['6.00 pm', 'Choral Evensong with the blessing of the new Icon of St Mary Magdalene']
# ..........................
# 2019-01-20 09:00:00
# {'servicedate': '2019-01-20 09:00:00', 'servicetype': 'College Eucharist', 'liturgicalday': 'Second Sunday After The Epiphany', 'hymns': '137, Christ is our light t. AM97, 47'}
# ..........................
# 2019-01-20 18:00:00
# {'servicedate': '2019-01-20 18:00:00', 'servicetype': 'Choral Evensong with the blessing of the new Icon of St Mary Magdalene', 'liturgicalday': 'Second Sunday After The Epiphany', 'responses': 'Oxley', 'psalm': '102 vv 1-11', 'canticles': 'Plainsong <i>Magnifica</i><i>t</i>; Wood <i>Nunc Dimittis</i>', 'anthem': 'Britten <i>New Year Carol</i>', 'preacher': 'The Master', 'sermon topic': 'Blessed are the poor in spirit', 'hymns': '174 t. 490, 52'}
# THURSDAY 24 JANUARY
#
# 6.15 pm	Choral Evensong
#
# Responses	Oxley
# Psalm		118 vv 19-29
# Canticles	Sumsion in G
# Anthem		Byrd Kyrie Eleison (4-part Mass)
# Hymns		48, 57
#
#
#
#
# ['6.15 pm', 'Choral Evensong']
# ..........................
# 2019-01-24 18:15:00
# {'servicedate': '2019-01-24 18:15:00', 'servicetype': 'Choral Evensong', 'liturgicalday': '', 'responses': 'Oxley', 'psalm': '118 vv 19-29', 'canticles': 'Sumsion in G', 'anthem': 'Byrd <i>Kyrie Eleison</i> <i>(4-part Mass)</i>', 'hymns': '48, 57'}
# SUNDAY 27 JANUARY
# THIRD SUNDAY AFTER THE EPIPHANY
#
#
#
# 9.00 am	College Eucharist
#
#
# Hymns		55, The kingdom of God t. AM 569i, 297
#
# 6.00 pm	Choral Evensong
#
# Responses	Oxley
# Psalm		120
# Canticles	Sumsion in G
# Anthem		Byrd Miserere Mei
# Sermon		The Chaplain Blessed are those who mourn
# Hymns		472ii, 82, 331
# ['9.00 am', 'College Eucharist']
# ['6.00 pm', 'Choral Evensong']
# ..........................
# 2019-01-27 09:00:00
# {'servicedate': '2019-01-27 09:00:00', 'servicetype': 'College Eucharist', 'liturgicalday': 'Third Sunday After The Epiphany', 'hymns': '55, The kingdom of God t. AM 569i, 297'}
# ..........................
# 2019-01-27 18:00:00
# {'servicedate': '2019-01-27 18:00:00', 'servicetype': 'Choral Evensong', 'liturgicalday': 'Third Sunday After The Epiphany', 'responses': 'Oxley', 'psalm': '120', 'canticles': 'Sumsion in G', 'anthem': 'Byrd <i>Miserere Mei</i>', 'preacher': 'The Chaplain', 'sermon topic': 'Blessed are those who mourn', 'hymns': '472ii, 82, 331'}
# WEDNESDAY 30 JANUARY
#
# 9.30pm	Choral Compline
#
#
# ['9.30pm', 'Choral Compline']
# ..........................
# 2019-01-30 21:30:00
# {'servicedate': '2019-01-30 21:30:00', 'servicetype': 'Choral Compline', 'liturgicalday': ''}
# THURSDAY 31 JANUARY
#
# 6.15 pm	Choral Evensong
#
# Responses	Oxley
# Psalm		145 vv 1-7
# Canticles	Howells Collegium Regale
# Anthem		Wesley Lead Me, Lord
# Hymns		358ii, 377
#
#
#
#
# ['6.15 pm', 'Choral Evensong']
# ..........................
# 2019-01-31 18:15:00
# {'servicedate': '2019-01-31 18:15:00', 'servicetype': 'Choral Evensong', 'liturgicalday': '', 'responses': 'Oxley', 'psalm': '145 vv 1-7', 'canticles': 'Howells <i>Collegium Regale</i>', 'anthem': 'Wesley <i>Lead Me, Lord</i>', 'hymns': '358ii, 377'}
# SUNDAY 3 FEBRUARY
# CANDLEMAS
#
# 9.00 am	College Eucharist
#
# Hymns	408i, Like a candle flame t. AM74, Christ be our light t. AM42
#
# 6.00 pm	Choral Evensong
#
# Responses	Rose
# Psalm		18 vv 1-15
# Canticles	Howells Collegium Regale
# Anthem		Wood Hail, Gladdening Light
# Sermon		The Reverend Jon Canessa Blessed are the meek
# Hymns		33 (vv 1,4,5,7), 44, 437
#
#
#
#
#
#
# ['9.00 am', 'College Eucharist']
# ['6.00 pm', 'Choral Evensong']
# ..........................
# 2019-02-03 09:00:00
# {'servicedate': '2019-02-03 09:00:00', 'servicetype': 'College Eucharist', 'liturgicalday': 'Candlemas', 'hymns': '408i, Like a candle flame t. AM74, Christ be our light t. AM42'}
# ..........................
# 2019-02-03 18:00:00
# {'servicedate': '2019-02-03 18:00:00', 'servicetype': 'Choral Evensong', 'liturgicalday': 'Candlemas', 'responses': 'Rose', 'psalm': '18 vv 1-15', 'canticles': 'Howells <i>Collegium Regale</i>', 'anthem': 'Wood <i>Hail, Gladdening Light</i>', 'preacher': 'The Reverend Jon Canessa', 'sermon topic': 'Blessed are the meek', 'hymns': '33\xa0(vv 1,4,5,7), 44, 437\xa0'}
# WEDNESDAY 6 FEBRUARY
#
# 6.15 pm	Corporate Communion
#
# 	Setting	Perosi Missa Secunda Pontificalis
# 	Motet	Tallis Verily, verily
# 	Hymns	427, 295, 415 t. 346
#
# ['6.15 pm', 'Corporate Communion']
# ..........................
# 2019-02-06 18:15:00
# {'servicedate': '2019-02-06 18:15:00', 'servicetype': 'Corporate Communion', 'liturgicalday': '', 'setting': 'Perosi <i>Missa</i> <i>Secunda</i> <i>Pontificalis</i>', 'motet': 'Tallis <i>Verily, verily</i>', 'hymns': '427, 295, 415 t. 346'}
# SUNDAY 10 FEBRUARY
# FIFTH SUNDAY AFTER THE EPIPHANY
#
#
#
# 9.00 am	College Eucharist
#
# Hymns		378, Above the voices t. AM114, 333
#
# 6.00 pm	Choral Evensong
#
# Responses	Rose
# Psalm		55 vv 1-15
# Canticles	Stanford in C
# Anthem		Brahms Geistliches Lied
# Sermon		Dr Pia de Simone Blessed are those who hunger
# Hymns		Come, my way t. The Call, 276, 368
#
#
# ['9.00 am', 'College Eucharist']
# ['6.00 pm', 'Choral Evensong']
# ..........................
# 2019-02-10 09:00:00
# {'servicedate': '2019-02-10 09:00:00', 'servicetype': 'College Eucharist', 'liturgicalday': 'Fifth Sunday After The Epiphany', 'hymns': '378, Above the voices t. AM114, 333'}
# ..........................
# 2019-02-10 18:00:00
# {'servicedate': '2019-02-10 18:00:00', 'servicetype': 'Choral Evensong', 'liturgicalday': 'Fifth Sunday After The Epiphany', 'responses': 'Rose', 'psalm': '55 vv 1-15', 'canticles': 'Stanford <i>in C</i>', 'anthem': 'Brahms <i>Geistliches</i> <i>Lied</i>', 'preacher': 'Dr Pia de Simone', 'sermon topic': 'Blessed are those who hunger', 'hymns': 'Come, my way t. The Call, 276, 368'}
# THURSDAY 14 February
#
# 6.15 pm	Choral Evensong
#
# Responses	Rose
# Psalm		74, 13-18
# Canticles	Dyson in C Minor
# Anthem		Byrd Sanctus and Benedictus (4-part Mass)
# Hymns		457, 446
#
#
#
#
#
# ['6.15 pm', 'Choral Evensong']
# ..........................
# 2019-02-14 18:15:00
# {'servicedate': '2019-02-14 18:15:00', 'servicetype': 'Choral Evensong', 'liturgicalday': '', 'responses': 'Rose', 'psalm': '74, 13-18', 'canticles': 'Dyson <i>in C Minor</i>', 'anthem': 'Byrd S<i>anctus and Benedictus</i> <i>(4-part Mass)</i>', 'hymns': '457, 446'}
# SUNDAY 17 FEBRUARY
# SEPTUAGESIMA
#
#
#
# 9.00 am	College Eucharist
#
# Hymns		52, Alleluia, raise the gospel t. AM556, 394
#
#
# 6.00 pm	Choral Evensong
#
# Responses	Rose
# Psalm		89 vv 1-8
# Canticles	Dyson in C Minor
# Anthem		Walford Davies Blest are the pure in heart
# Sermon		Dr Elaine Storkey Blessed are the pure in heart
# Hymns		431, 341, 473 (vv 1, 6-8)
#
#
# ['9.00 am', 'College Eucharist']
# ['6.00 pm', 'Choral Evensong']
# ..........................
# 2019-02-17 09:00:00
# {'servicedate': '2019-02-17 09:00:00', 'servicetype': 'College Eucharist', 'liturgicalday': 'Septuagesima', 'hymns': '52, Alleluia, raise the gospel t. AM556, 394'}
# ..........................
# 2019-02-17 18:00:00
# {'servicedate': '2019-02-17 18:00:00', 'servicetype': 'Choral Evensong', 'liturgicalday': 'Septuagesima', 'responses': 'Rose', 'psalm': '89 vv 1-8', 'canticles': 'Dyson <i>in C Minor</i>', 'anthem': 'Walford Davies <i>Blest are the pure in heart</i>', 'preacher': 'Dr Elaine Storkey', 'sermon topic': 'Blessed are the pure in heart', 'hymns': '431, 341, 473 (vv 1, 6-8)'}
# FRIDAY 22 FEBRUARY
# SAMUEL PEPYS’ BIRTHDAY
#
#
# 6.00 pm	Choral Evensong
#
# Responses	Tomkins
# Psalm		107 vv 23-30
# Canticles	Gibbons Second Service
# Anthem		Gibbons O clap your hands
# Hymns		373 t Coe Fen, 436
#
#
#
# ['6.00 pm', 'Choral Evensong']
# ..........................
# 2019-02-22 18:00:00
# {'servicedate': '2019-02-22 18:00:00', 'servicetype': 'Choral Evensong', 'liturgicalday': 'Samuel Pepys’ Birthday', 'responses': 'Tomkins', 'psalm': '107 vv 23-30', 'canticles': 'Gibbons <i>Second Service</i>', 'anthem': 'Gibbons <i>O clap your hands</i>', 'hymns': '373 t Coe Fen<i>,</i> 436'}
# SUNDAY 24 FEBRUARY
# SEXUAGESIMA/SAINT MATTHIAS
#
#
# 9.00 am	Holy Communion
#
# Hymns		354, 274, O Lord my God
#
#
# 6.00 pm	Choral Evensong
#
# Responses	Tomkins
# Psalm		119 vv 1-16
# Canticles	Gibbons Second Service
# Anthem		Mendelssohn Verleih uns Frieden
# Sermon		Monsignor Mark Langham Blessed are the   peacemakers
# Hymns		394, Peace, Perfect Peace t. 82, 361
#
#
#
# ['9.00 am', 'Holy Communion']
# ['6.00 pm', 'Choral Evensong']
# ..........................
# 2019-02-24 09:00:00
# {'servicedate': '2019-02-24 09:00:00', 'servicetype': 'Holy Communion', 'liturgicalday': 'Sexuagesima/Saint Matthias', 'hymns': '354, 274, O Lord my God'}
# ..........................
# 2019-02-24 18:00:00
# {'servicedate': '2019-02-24 18:00:00', 'servicetype': 'Choral Evensong', 'liturgicalday': 'Sexuagesima/Saint Matthias', 'responses': 'Tomkins', 'psalm': '119 vv 1-16', 'canticles': 'Gibbons <i>Second Service</i>', 'anthem': 'Mendelssohn <i>Verleih</i> <i>uns</i> <i>Frieden</i>', 'preacher': 'Monsignor Mark Langham', 'sermon topic': 'Blessed are the   peacemakers', 'hymns': '394, Peace, Perfect Peace t. 82, 361'}
# WEDNESDAY 27 FEBRUARY
#
# 9.30pm	Choral Compline
#
#
# ['9.30pm', 'Choral Compline']
# ..........................
# 2019-02-27 21:30:00
# {'servicedate': '2019-02-27 21:30:00', 'servicetype': 'Choral Compline', 'liturgicalday': ''}
# THURSDAY 28 FEBRUARY
#
# 6.15 pm	Choral Evensong
#
# Responses	Tomkins
# Psalm		137
# Canticles	Brewer In D
# Anthem		Tallis If ye love me
# Hymns		294, 357
# ['6.15 pm', 'Choral Evensong']
# ..........................
# 2019-02-28 18:15:00
# {'servicedate': '2019-02-28 18:15:00', 'servicetype': 'Choral Evensong', 'liturgicalday': '', 'responses': 'Tomkins', 'psalm': '137', 'canticles': 'Brewer <i>In D</i>', 'anthem': 'Tallis <i>If ye love me</i>', 'hymns': '294, 357'}
# SUNDAY 3 MARCH
# QUINQAGESIMA
#
#
#
# 9.00 am	College Eucharist
#
# Hymns		433, Jesus on the mountain peak (t. St Albinus), There is a redeemer t. AM 805
#
#
# 6.00 pm	Choral Evensong
#
# Responses	Tomkins
# Psalm		15
# Canticles	Brewer In D
# Anthem		Purcell Remember not, O Lord
# Sermon		Dr Muthuraj Swamy Blessed are the persecuted
# Hymns		383ii, 414, And can it be
#
#
#
#
#
# ['9.00 am', 'College Eucharist']
# ['6.00 pm', 'Choral Evensong']
# ..........................
# 2019-03-03 09:00:00
# {'servicedate': '2019-03-03 09:00:00', 'servicetype': 'College Eucharist', 'liturgicalday': 'Quinqagesima', 'hymns': '433, Jesus on the mountain peak (t. St Albinus), There is a redeemer t. AM 805'}
# ..........................
# 2019-03-03 18:00:00
# {'servicedate': '2019-03-03 18:00:00', 'servicetype': 'Choral Evensong', 'liturgicalday': 'Quinqagesima', 'responses': 'Tomkins', 'psalm': '15', 'canticles': 'Brewer <i>In D</i> ', 'anthem': 'Purcell <i>Remember not, O Lord</i>', 'preacher': 'Dr Muthuraj Swamy', 'sermon topic': 'Blessed are the persecuted', 'hymns': '383ii, 414, And can it be'}
# WEDNESDAY 6 MARCH
#
# ASH WEDNESDAY
#
#
#
# 6..00 pm	Communion with ceremony of ashing
# Setting		Byrd 4-part Mass
# Motet		Byrd Miserere Mei
# Hymns		70, 76, 75
#
#
#
#
#
#
#
#
# SUNDAY 10 MARCH
# FIRST SUNDAY IN LENT
#
#
#
# 9.00 am	College Eucharist
#
# Hymns		67, 357, 420
#
# 6.00 pm	Lenten Service of Readings and Music
#
#
#
#
#
#
#
#
# ['9.00 am', 'College Eucharist']
# ['6.00 pm', 'Lenten Service of Readings and Music']
# ..........................
# 2019-03-10 09:00:00
# {'servicedate': '2019-03-10 09:00:00', 'servicetype': 'College Eucharist', 'liturgicalday': 'First Sunday In Lent', 'hymns': '67, 357, 420'}
# ..........................
# 2019-03-10 18:00:00
# {'servicedate': '2019-03-10 18:00:00', 'servicetype': 'Lenten Service of Readings and Music', 'liturgicalday': 'First Sunday In Lent'}
# THURSDAY 14 MARCH
#
#
# 6.15 pm	Choral Evensong
#
# Responses	Tomkins
# Psalm		74 1-12
# Canticles	Plainsong Magnificat; Wood Nunc Dimittis
# Anthem		Rheinberger Abendlied
# Hymns		84, 86
#
#
#
#
#
# ['6.15 pm', 'Choral Evensong']
# ..........................
# 2019-03-14 18:15:00
# {'servicedate': '2019-03-14 18:15:00', 'servicetype': 'Choral Evensong', 'liturgicalday': '', 'responses': 'Tomkins', 'psalm': '74 1-12', 'canticles': 'Plainsong <i>Magnificat</i>; Wood <i>Nunc Dimittis</i>', 'anthem': 'Rheinberger <i>Abendlied</i>', 'hymns': '84, 86'}
# SUNDAY 18 MARCH
# FOURTH SUNDAY IN LENT
#
#
#
# 9.00 am	College Eucharist
#
#
#
#
#
# Services are discontinued until Easter Day, Sunday 21 April 2019
#
# ['9.00 am', 'College Eucharist']
# ..........................
# 2019-03-18 09:00:00
# {'servicedate': '2019-03-18 09:00:00', 'servicetype': 'College Eucharist', 'liturgicalday': 'Fourth Sunday In Lent'}
# Lent
# 2019
# {'servicedate': '2019-01-20 09:00:00', 'servicetype': 'College Eucharist', 'liturgicalday': 'Second Sunday After The Epiphany', 'hymns': '137, Christ is our light t. AM97, 47'}
#
# {'servicedate': '2019-01-20 18:00:00', 'servicetype': 'Choral Evensong with the blessing of the new Icon of St Mary Magdalene', 'liturgicalday': 'Second Sunday After The Epiphany', 'responses': 'Oxley', 'psalm': '102 vv 1-11', 'canticles': 'Plainsong <i>Magnifica</i><i>t</i>; Wood <i>Nunc Dimittis</i>', 'anthem': 'Britten <i>New Year Carol</i>', 'preacher': 'The Master', 'sermon topic': 'Blessed are the poor in spirit', 'hymns': '174 t. 490, 52'}
#
# {'servicedate': '2019-01-24 18:15:00', 'servicetype': 'Choral Evensong', 'liturgicalday': '', 'responses': 'Oxley', 'psalm': '118 vv 19-29', 'canticles': 'Sumsion in G', 'anthem': 'Byrd <i>Kyrie Eleison</i> <i>(4-part Mass)</i>', 'hymns': '48, 57'}
#
# {'servicedate': '2019-01-27 09:00:00', 'servicetype': 'College Eucharist', 'liturgicalday': 'Third Sunday After The Epiphany', 'hymns': '55, The kingdom of God t. AM 569i, 297'}
#
# {'servicedate': '2019-01-27 18:00:00', 'servicetype': 'Choral Evensong', 'liturgicalday': 'Third Sunday After The Epiphany', 'responses': 'Oxley', 'psalm': '120', 'canticles': 'Sumsion in G', 'anthem': 'Byrd <i>Miserere Mei</i>', 'preacher': 'The Chaplain', 'sermon topic': 'Blessed are those who mourn', 'hymns': '472ii, 82, 331'}
#
# {'servicedate': '2019-01-30 21:30:00', 'servicetype': 'Choral Compline', 'liturgicalday': ''}
#
# {'servicedate': '2019-01-31 18:15:00', 'servicetype': 'Choral Evensong', 'liturgicalday': '', 'responses': 'Oxley', 'psalm': '145 vv 1-7', 'canticles': 'Howells <i>Collegium Regale</i>', 'anthem': 'Wesley <i>Lead Me, Lord</i>', 'hymns': '358ii, 377'}
#
# {'servicedate': '2019-02-03 09:00:00', 'servicetype': 'College Eucharist', 'liturgicalday': 'Candlemas', 'hymns': '408i, Like a candle flame t. AM74, Christ be our light t. AM42'}
#
# {'servicedate': '2019-02-03 18:00:00', 'servicetype': 'Choral Evensong', 'liturgicalday': 'Candlemas', 'responses': 'Rose', 'psalm': '18 vv 1-15', 'canticles': 'Howells <i>Collegium Regale</i>', 'anthem': 'Wood <i>Hail, Gladdening Light</i>', 'preacher': 'The Reverend Jon Canessa', 'sermon topic': 'Blessed are the meek', 'hymns': '33\xa0(vv 1,4,5,7), 44, 437\xa0'}
#
# {'servicedate': '2019-02-06 18:15:00', 'servicetype': 'Corporate Communion', 'liturgicalday': '', 'setting': 'Perosi <i>Missa</i> <i>Secunda</i> <i>Pontificalis</i>', 'motet': 'Tallis <i>Verily, verily</i>', 'hymns': '427, 295, 415 t. 346'}
#
# {'servicedate': '2019-02-10 09:00:00', 'servicetype': 'College Eucharist', 'liturgicalday': 'Fifth Sunday After The Epiphany', 'hymns': '378, Above the voices t. AM114, 333'}
#
# {'servicedate': '2019-02-10 18:00:00', 'servicetype': 'Choral Evensong', 'liturgicalday': 'Fifth Sunday After The Epiphany', 'responses': 'Rose', 'psalm': '55 vv 1-15', 'canticles': 'Stanford <i>in C</i>', 'anthem': 'Brahms <i>Geistliches</i> <i>Lied</i>', 'preacher': 'Dr Pia de Simone', 'sermon topic': 'Blessed are those who hunger', 'hymns': 'Come, my way t. The Call, 276, 368'}
#
# {'servicedate': '2019-02-14 18:15:00', 'servicetype': 'Choral Evensong', 'liturgicalday': '', 'responses': 'Rose', 'psalm': '74, 13-18', 'canticles': 'Dyson <i>in C Minor</i>', 'anthem': 'Byrd S<i>anctus and Benedictus</i> <i>(4-part Mass)</i>', 'hymns': '457, 446'}
#
# {'servicedate': '2019-02-17 09:00:00', 'servicetype': 'College Eucharist', 'liturgicalday': 'Septuagesima', 'hymns': '52, Alleluia, raise the gospel t. AM556, 394'}
#
# {'servicedate': '2019-02-17 18:00:00', 'servicetype': 'Choral Evensong', 'liturgicalday': 'Septuagesima', 'responses': 'Rose', 'psalm': '89 vv 1-8', 'canticles': 'Dyson <i>in C Minor</i>', 'anthem': 'Walford Davies <i>Blest are the pure in heart</i>', 'preacher': 'Dr Elaine Storkey', 'sermon topic': 'Blessed are the pure in heart', 'hymns': '431, 341, 473 (vv 1, 6-8)'}
#
# {'servicedate': '2019-02-22 18:00:00', 'servicetype': 'Choral Evensong', 'liturgicalday': 'Samuel Pepys’ Birthday', 'responses': 'Tomkins', 'psalm': '107 vv 23-30', 'canticles': 'Gibbons <i>Second Service</i>', 'anthem': 'Gibbons <i>O clap your hands</i>', 'hymns': '373 t Coe Fen<i>,</i> 436'}
#
# {'servicedate': '2019-02-24 09:00:00', 'servicetype': 'Holy Communion', 'liturgicalday': 'Sexuagesima/Saint Matthias', 'hymns': '354, 274, O Lord my God'}
#
# {'servicedate': '2019-02-24 18:00:00', 'servicetype': 'Choral Evensong', 'liturgicalday': 'Sexuagesima/Saint Matthias', 'responses': 'Tomkins', 'psalm': '119 vv 1-16', 'canticles': 'Gibbons <i>Second Service</i>', 'anthem': 'Mendelssohn <i>Verleih</i> <i>uns</i> <i>Frieden</i>', 'preacher': 'Monsignor Mark Langham', 'sermon topic': 'Blessed are the   peacemakers', 'hymns': '394, Peace, Perfect Peace t. 82, 361'}
#
# {'servicedate': '2019-02-27 21:30:00', 'servicetype': 'Choral Compline', 'liturgicalday': ''}
#
# {'servicedate': '2019-02-28 18:15:00', 'servicetype': 'Choral Evensong', 'liturgicalday': '', 'responses': 'Tomkins', 'psalm': '137', 'canticles': 'Brewer <i>In D</i>', 'anthem': 'Tallis <i>If ye love me</i>', 'hymns': '294, 357'}
#
# {'servicedate': '2019-03-03 09:00:00', 'servicetype': 'College Eucharist', 'liturgicalday': 'Quinqagesima', 'hymns': '433, Jesus on the mountain peak (t. St Albinus), There is a redeemer t. AM 805'}
#
# {'servicedate': '2019-03-03 18:00:00', 'servicetype': 'Choral Evensong', 'liturgicalday': 'Quinqagesima', 'responses': 'Tomkins', 'psalm': '15', 'canticles': 'Brewer <i>In D</i> ', 'anthem': 'Purcell <i>Remember not, O Lord</i>', 'preacher': 'Dr Muthuraj Swamy', 'sermon topic': 'Blessed are the persecuted', 'hymns': '383ii, 414, And can it be'}
#
# {'servicedate': '2019-03-10 09:00:00', 'servicetype': 'College Eucharist', 'liturgicalday': 'First Sunday In Lent', 'hymns': '67, 357, 420'}
#
# {'servicedate': '2019-03-10 18:00:00', 'servicetype': 'Lenten Service of Readings and Music', 'liturgicalday': 'First Sunday In Lent'}
#
# {'servicedate': '2019-03-14 18:15:00', 'servicetype': 'Choral Evensong', 'liturgicalday': '', 'responses': 'Tomkins', 'psalm': '74 1-12', 'canticles': 'Plainsong <i>Magnificat</i>; Wood <i>Nunc Dimittis</i>', 'anthem': 'Rheinberger <i>Abendlied</i>', 'hymns': '84, 86'}
#
# {'servicedate': '2019-03-18 09:00:00', 'servicetype': 'College Eucharist', 'liturgicalday': 'Fourth Sunday In Lent'}
#
# output\Service booklet L19 v3.xlsx

# %%
ml.musiclist_df
# Out:
#                                                  servicetype  \
# serviceid
# NaN                                        College Eucharist
# NaN        Choral Evensong with the blessing of the new I...
# NaN                                          Choral Evensong
# NaN                                        College Eucharist
# NaN                                          Choral Evensong
# NaN                                          Choral Compline
# NaN                                          Choral Evensong
# NaN                                        College Eucharist
# NaN                                          Choral Evensong
# NaN                                      Corporate Communion
# NaN                                        College Eucharist
# NaN                                          Choral Evensong
# NaN                                          Choral Evensong
# NaN                                        College Eucharist
# NaN                                          Choral Evensong
# NaN                                          Choral Evensong
# NaN                                           Holy Communion
# NaN                                          Choral Evensong
# NaN                                          Choral Compline
# NaN                                          Choral Evensong
# NaN                                        College Eucharist
# NaN                                          Choral Evensong
# NaN                                        College Eucharist
# NaN                     Lenten Service of Readings and Music
# NaN                                          Choral Evensong
# NaN                                        College Eucharist
#
#                    servicedate                     liturgicalday  \
# serviceid
# NaN        2019-01-20 09:00:00  Second Sunday After The Epiphany
# NaN        2019-01-20 18:00:00  Second Sunday After The Epiphany
# NaN        2019-01-24 18:15:00
# NaN        2019-01-27 09:00:00   Third Sunday After The Epiphany
# NaN        2019-01-27 18:00:00   Third Sunday After The Epiphany
# NaN        2019-01-30 21:30:00
# NaN        2019-01-31 18:15:00
# NaN        2019-02-03 09:00:00                         Candlemas
# NaN        2019-02-03 18:00:00                         Candlemas
# NaN        2019-02-06 18:15:00
# NaN        2019-02-10 09:00:00   Fifth Sunday After The Epiphany
# NaN        2019-02-10 18:00:00   Fifth Sunday After The Epiphany
# NaN        2019-02-14 18:15:00
# NaN        2019-02-17 09:00:00                      Septuagesima
# NaN        2019-02-17 18:00:00                      Septuagesima
# NaN        2019-02-22 18:00:00            Samuel Pepys’ Birthday
# NaN        2019-02-24 09:00:00        Sexuagesima/Saint Matthias
# NaN        2019-02-24 18:00:00        Sexuagesima/Saint Matthias
# NaN        2019-02-27 21:30:00
# NaN        2019-02-28 18:15:00
# NaN        2019-03-03 09:00:00                      Quinqagesima
# NaN        2019-03-03 18:00:00                      Quinqagesima
# NaN        2019-03-10 09:00:00              First Sunday In Lent
# NaN        2019-03-10 18:00:00              First Sunday In Lent
# NaN        2019-03-14 18:15:00
# NaN        2019-03-18 09:00:00             Fourth Sunday In Lent
#
#                                                        hymns  introit  \
# serviceid
# NaN                     137, Christ is our light t. AM97, 47      NaN
# NaN                                           174 t. 490, 52      NaN
# NaN                                                   48, 57      NaN
# NaN                   55, The kingdom of God t. AM 569i, 297      NaN
# NaN                                           472ii, 82, 331      NaN
# NaN                                                      NaN      NaN
# NaN                                               358ii, 377      NaN
# NaN        408i, Like a candle flame t. AM74, Christ be o...      NaN
# NaN                                33 (vv 1,4,5,7), 44, 437       NaN
# NaN                                     427, 295, 415 t. 346      NaN
# NaN                      378, Above the voices t. AM114, 333      NaN
# NaN                       Come, my way t. The Call, 276, 368      NaN
# NaN                                                 457, 446      NaN
# NaN             52, Alleluia, raise the gospel t. AM556, 394      NaN
# NaN                                431, 341, 473 (vv 1, 6-8)      NaN
# NaN                                373 t Coe Fen<i>,</i> 436      NaN
# NaN                                  354, 274, O Lord my God      NaN
# NaN                     394, Peace, Perfect Peace t. 82, 361      NaN
# NaN                                                      NaN      NaN
# NaN                                                 294, 357      NaN
# NaN        433, Jesus on the mountain peak (t. St Albinus...      NaN
# NaN                                383ii, 414, And can it be      NaN
# NaN                                             67, 357, 420      NaN
# NaN                                                      NaN      NaN
# NaN                                                   84, 86      NaN
# NaN                                                      NaN      NaN
#
#           responses         psalm  \
# serviceid
# NaN             NaN           NaN
# NaN           Oxley   102 vv 1-11
# NaN           Oxley  118 vv 19-29
# NaN             NaN           NaN
# NaN           Oxley           120
# NaN             NaN           NaN
# NaN           Oxley    145 vv 1-7
# NaN             NaN           NaN
# NaN            Rose    18 vv 1-15
# NaN             NaN           NaN
# NaN             NaN           NaN
# NaN            Rose    55 vv 1-15
# NaN            Rose     74, 13-18
# NaN             NaN           NaN
# NaN            Rose     89 vv 1-8
# NaN         Tomkins  107 vv 23-30
# NaN             NaN           NaN
# NaN         Tomkins   119 vv 1-16
# NaN             NaN           NaN
# NaN         Tomkins           137
# NaN             NaN           NaN
# NaN         Tomkins            15
# NaN             NaN           NaN
# NaN             NaN           NaN
# NaN         Tomkins       74 1-12
# NaN             NaN           NaN
#
#                                                    canticles  \
# serviceid
# NaN                                                      NaN
# NaN        Plainsong <i>Magnifica</i><i>t</i>; Wood <i>Nu...
# NaN                                             Sumsion in G
# NaN                                                      NaN
# NaN                                             Sumsion in G
# NaN                                                      NaN
# NaN                          Howells <i>Collegium Regale</i>
# NaN                                                      NaN
# NaN                          Howells <i>Collegium Regale</i>
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                     Stanford <i>in C</i>
# NaN                                  Dyson <i>in C Minor</i>
# NaN                                                      NaN
# NaN                                  Dyson <i>in C Minor</i>
# NaN                            Gibbons <i>Second Service</i>
# NaN                                                      NaN
# NaN                            Gibbons <i>Second Service</i>
# NaN                                                      NaN
# NaN                                       Brewer <i>In D</i>
# NaN                                                      NaN
# NaN                                      Brewer <i>In D</i>
# NaN                                                      NaN
# NaN                                                      NaN
# NaN        Plainsong <i>Magnificat</i>; Wood <i>Nunc Dimi...
# NaN                                                      NaN
#
#                                                       anthem  requiem  \
# serviceid
# NaN                                                      NaN      NaN
# NaN                            Britten <i>New Year Carol</i>      NaN
# NaN           Byrd <i>Kyrie Eleison</i> <i>(4-part Mass)</i>      NaN
# NaN                                                      NaN      NaN
# NaN                                 Byrd <i>Miserere Mei</i>      NaN
# NaN                                                      NaN      NaN
# NaN                              Wesley <i>Lead Me, Lord</i>      NaN
# NaN                                                      NaN      NaN
# NaN                       Wood <i>Hail, Gladdening Light</i>      NaN
# NaN                                                      NaN      NaN
# NaN                                                      NaN      NaN
# NaN                    Brahms <i>Geistliches</i> <i>Lied</i>      NaN
# NaN        Byrd S<i>anctus and Benedictus</i> <i>(4-part ...      NaN
# NaN                                                      NaN      NaN
# NaN        Walford Davies <i>Blest are the pure in heart</i>      NaN
# NaN                         Gibbons <i>O clap your hands</i>      NaN
# NaN                                                      NaN      NaN
# NaN        Mendelssohn <i>Verleih</i> <i>uns</i> <i>Fried...      NaN
# NaN                                                      NaN      NaN
# NaN                              Tallis <i>If ye love me</i>      NaN
# NaN                                                      NaN      NaN
# NaN                      Purcell <i>Remember not, O Lord</i>      NaN
# NaN                                                      NaN      NaN
# NaN                                                      NaN      NaN
# NaN                             Rheinberger <i>Abendlied</i>      NaN
# NaN                                                      NaN      NaN
#
#                                                      setting  \
# serviceid
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN        Perosi <i>Missa</i> <i>Secunda</i> <i>Pontific...
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
# NaN                                                      NaN
#
#                                   motet  cantata                  preacher  \
# serviceid
# NaN                                 NaN      NaN                       NaN
# NaN                                 NaN      NaN                The Master
# NaN                                 NaN      NaN                       NaN
# NaN                                 NaN      NaN                       NaN
# NaN                                 NaN      NaN              The Chaplain
# NaN                                 NaN      NaN                       NaN
# NaN                                 NaN      NaN                       NaN
# NaN                                 NaN      NaN                       NaN
# NaN                                 NaN      NaN  The Reverend Jon Canessa
# NaN        Tallis <i>Verily, verily</i>      NaN                       NaN
# NaN                                 NaN      NaN                       NaN
# NaN                                 NaN      NaN          Dr Pia de Simone
# NaN                                 NaN      NaN                       NaN
# NaN                                 NaN      NaN                       NaN
# NaN                                 NaN      NaN         Dr Elaine Storkey
# NaN                                 NaN      NaN                       NaN
# NaN                                 NaN      NaN                       NaN
# NaN                                 NaN      NaN    Monsignor Mark Langham
# NaN                                 NaN      NaN                       NaN
# NaN                                 NaN      NaN                       NaN
# NaN                                 NaN      NaN                       NaN
# NaN                                 NaN      NaN         Dr Muthuraj Swamy
# NaN                                 NaN      NaN                       NaN
# NaN                                 NaN      NaN                       NaN
# NaN                                 NaN      NaN                       NaN
# NaN                                 NaN      NaN                       NaN
#
#                              sermon topic  voluntary  organist  extranotes
# serviceid
# NaN                                   NaN        NaN       NaN         NaN
# NaN        Blessed are the poor in spirit        NaN       NaN         NaN
# NaN                                   NaN        NaN       NaN         NaN
# NaN                                   NaN        NaN       NaN         NaN
# NaN           Blessed are those who mourn        NaN       NaN         NaN
# NaN                                   NaN        NaN       NaN         NaN
# NaN                                   NaN        NaN       NaN         NaN
# NaN                                   NaN        NaN       NaN         NaN
# NaN                  Blessed are the meek        NaN       NaN         NaN
# NaN                                   NaN        NaN       NaN         NaN
# NaN                                   NaN        NaN       NaN         NaN
# NaN          Blessed are those who hunger        NaN       NaN         NaN
# NaN                                   NaN        NaN       NaN         NaN
# NaN                                   NaN        NaN       NaN         NaN
# NaN         Blessed are the pure in heart        NaN       NaN         NaN
# NaN                                   NaN        NaN       NaN         NaN
# NaN                                   NaN        NaN       NaN         NaN
# NaN         Blessed are the   peacemakers        NaN       NaN         NaN
# NaN                                   NaN        NaN       NaN         NaN
# NaN                                   NaN        NaN       NaN         NaN
# NaN                                   NaN        NaN       NaN         NaN
# NaN            Blessed are the persecuted        NaN       NaN         NaN
# NaN                                   NaN        NaN       NaN         NaN
# NaN                                   NaN        NaN       NaN         NaN
# NaN                                   NaN        NaN       NaN         NaN
# NaN                                   NaN        NaN       NaN         NaN
